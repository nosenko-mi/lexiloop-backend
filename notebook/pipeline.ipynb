# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /home/nmi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/nmi/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text = '"What a curious feeling!" said Alice; "I must be shutting up like a telescope."'

# %%
import re


text = '"What a curious feeling!" said Alice; "I must be shutting up like a telescope."'

sentences = re.split(r'(?<=[.!?"]) +', text)

sentences
# Out:
# ['"What a curious feeling!"',
#  'said Alice; "I must be shutting up like a telescope."']

# %%
from nltk import word_tokenize


tokenized_sentence = word_tokenize(sentences[0])
print(tokenized_sentence)
# Out:
# ['``', 'What', 'a', 'curious', 'feeling', '!', "''"]

# %%
print(nltk.pos_tag(tokenized_sentence))
# Out:
# [('``', '``'), ('What', 'WP'), ('a', 'DT'), ('curious', 'JJ'), ('feeling', 'NN'), ('!', '.'), ("''", "''")]
